# %% [markdown]
# <a href="https://colab.research.google.com/github/VeeramShah/QuantVision_VeeramShah---BCS/blob/main/Assignment%201/Assignment1_VeeramShah/VeeramShah_Assignment1_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP.**
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Import matplotlib.pyplot as plt**

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
#
# **Follow along with these steps**
# * Create a figure object called fig using plt.figure()
# * Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.
# * Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
x = [0, 20, 40, 60, 80]
y = [0,50,100,150,200]

fig = plt.figure() #Creating figure
ax = fig.add_axes([0,0,1,1]) #Creating axes
ax.plot(x,y)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_title("title")
plt.show()

# %% [markdown]
# ## Exercise 2
# **Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig2  = plt.figure()
ax1 = fig2.add_axes([0,0,1,1])
ax2 = fig2.add_axes([0.2,0.5,.2,.2])
plt.show()

# %% [markdown]
# **Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig3  = plt.figure()
ax_1 = fig3.add_axes([0,0,1,1])
ax_2 = fig3.add_axes([0.2,0.5,.2,.2])
ax_1.plot(x,y)
ax_2.plot(x,y)
plt.show()

# %% [markdown]
# ## Exercise 3
#
# **Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig4 = plt.figure()
ax__1 = fig4.add_axes([0,0,1,1])
ax__2 = fig4.add_axes( [0.2,0.5,0.4,0.4])
plt.show()

# %% [markdown]
# **Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
x1 = np.arange(0,100)
y1 = x1 + 20
z1 = x1**2

fig5 = plt.figure()
ax1_ = fig5.add_axes([0,0,1,1])
ax1_.plot(x1,z1)
ax1_.set_xlabel("x")
ax1_.set_ylabel("z")

ax2_ = fig5.add_axes([0.2,0.5,0.4,0.])
ax2_.plot(x1,y1)
ax2_.set_xlim(20,22)
ax2_.set_ylim(30,50)
ax2_.set_xlabel("x")
ax2_.set_ylabel("y")
ax2_.set_title("zoom")

plt.show() #yeh wala nahi ho raha hai

# %% [markdown]
# ## Exercise 4
#
# **Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig, axes = plt.subplots(1,2)
plt.show()

# %% [markdown]
# **Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
x2 = np.arange(0,101)
y2 = 2*x2
z2 = x2**2

fig, axes = plt.subplots(1,2)
axes[0].plot(x2,y2, color="blue", linestyle="--")
axes[1].plot(x2,z2, color="red")
plt.show()

# %% [markdown]
# **See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
x2 = np.arange(0,101)
y2 = 2*x2
z2 = x2**2

fig, axes = plt.subplots(1,2, figsize=(10,4))
axes[0].plot(x2,y2, color="blue", linestyle="--")
axes[1].plot(x2,z2, color="red")
plt.show()

# %% [markdown]
# # Great Job!
